# 11         Regular Season  1000243.0              Highbury Stadium
# 12         Regular Season  1000243.0              Highbury Stadium
# 13         Regular Season  1000243.0              Highbury Stadium
# 14         Regular Season        2.0                  Old Trafford
# 15         Regular Season  1000243.0              Highbury Stadium
# 16         Regular Season     4715.0                Etihad Stadium
# 17         Regular Season       10.0               Stamford Bridge
# 18         Regular Season    99148.0               White Hart Lane
# 19         Regular Season     4591.0           St. Mary''s Stadium
# 20         Regular Season  1000243.0              Highbury Stadium
# 21         Regular Season     4500.0           St. Andrews Stadium
# 22         Regular Season  1000243.0              Highbury Stadium
# 23         Regular Season  1000243.0              Highbury Stadium
# 24         Regular Season  1000243.0              Highbury Stadium
# 25         Regular Season  1000243.0              Highbury Stadium
# 26         Regular Season  1000243.0              Highbury Stadium
# 27         Regular Season     4843.0  University of Bolton Stadium
# 28         Regular Season     4844.0                   Loftus Road
# 29         Regular Season        NaN                           NaN
# 30         Regular Season        NaN                           NaN
# 31         Regular Season        NaN                           NaN
# 32         Regular Season        NaN                           NaN
# 33         Regular Season        NaN                           NaN
# 34         Regular Season  1000243.0              Highbury Stadium
# 35         Regular Season  1000243.0              Highbury Stadium
# 36         Regular Season       31.0                    The Valley
# 37         Regular Season     4674.0              St. James'' Park
#
#    stadium_country_id  stadium_country_name referee_id   referee_name  \
# 0                68.0               England        NaN            NaN
# 1                68.0               England        NaN            NaN
# 2                68.0               England        NaN            NaN
# 3                68.0               England        NaN            NaN
# 4                68.0               England        NaN            NaN
# 5                68.0               England        NaN            NaN
# 6                68.0               England        NaN            NaN
# 7                68.0               England        NaN            NaN
# 8                68.0               England        NaN            NaN
# 9                68.0               England        NaN            NaN
# 10               68.0               England        NaN            NaN
# 11               68.0               England        NaN            NaN
# 12               68.0               England        NaN            NaN
# 13               68.0               England        NaN            NaN
# 14               68.0               England        NaN            NaN
# 15               68.0               England        NaN            NaN
# 16               68.0               England        NaN            NaN
# 17               68.0               England        NaN            NaN
# 18               68.0               England        NaN            NaN
# 19               68.0               England        NaN            NaN
# 20               68.0               England        NaN            NaN
# 21               68.0               England        NaN            NaN
# 22               68.0               England        NaN            NaN
# 23               68.0               England        NaN            NaN
# 24               68.0               England        NaN            NaN
# 25               68.0               England        NaN            NaN
# 26               68.0               England        NaN            NaN
# 27               68.0               England        NaN            NaN
# 28               68.0               England        NaN            NaN
# 29                NaN                   NaN      669.0  Michael Riley
# 30                NaN                   NaN  1008015.0  Robert Styles
# 31                NaN                   NaN  1008017.0    Neale Barry
# 32                NaN                   NaN  1008016.0     Alan Wiley
# 33                NaN                   NaN        NaN            NaN
# 34               68.0               England        NaN            NaN
# 35               68.0               England        NaN            NaN
# 36               68.0               England        NaN            NaN
# 37               68.0               England        NaN            NaN
#
#    referee_country_id  referee_country_name
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4                 NaN                   NaN
# 5                 NaN                   NaN
# 6                 NaN                   NaN
# 7                 NaN                   NaN
# 8                 NaN                   NaN
# 9                 NaN                   NaN
# 10                NaN                   NaN
# 11                NaN                   NaN
# 12                NaN                   NaN
# 13                NaN                   NaN
# 14                NaN                   NaN
# 15                NaN                   NaN
# 16                NaN                   NaN
# 17                NaN                   NaN
# 18                NaN                   NaN
# 19                NaN                   NaN
# 20                NaN                   NaN
# 21                NaN                   NaN
# 22                NaN                   NaN
# 23                NaN                   NaN
# 24                NaN                   NaN
# 25                NaN                   NaN
# 26                NaN                   NaN
# 27                NaN                   NaN
# 28                NaN                   NaN
# 29               68.0               England
# 30               68.0               England
# 31               68.0               England
# 32               68.0               England
# 33                NaN                   NaN
# 34                NaN                   NaN
# 35                NaN                   NaN
# 36                NaN                   NaN
# 37                NaN                   NaN
#
# [38 rows x 52 columns]

# %%
parser.match(competition_id =2,season_id = 44).loc[0]
# Out:
# match_id                                              3749052
# match_date                                2004-02-07 00:00:00
# kick_off                                  2004-02-07 16:00:00
# home_score                                                  1
# away_score                                                  3
# match_status                                        available
# match_status_360                                    scheduled
# last_updated                              2020-07-29 05:00:00
# last_updated_360                   2021-06-13 16:17:31.694000
# match_week                                                  2
# competition_id                                              2
# country_name                                          England
# competition_name                               Premier League
# season_id                                                  44
# season_name                                         2003/2004
# home_team_id                                               46
# home_team_name                        Wolverhampton Wanderers
# home_team_gender                                         male
# home_team_group                                          None
# home_team_country_id                                       68
# home_team_country_name                                England
# home_team_managers_id                                  3602.0
# home_team_managers_name                            Dave Jones
# home_team_managers_nickname                        Dave Jones
# home_team_managers_dob                    1956-08-17 00:00:00
# home_team_managers_country_id                            68.0
# home_team_managers_country_name                       England
# away_team_id                                                1
# away_team_name                                        Arsenal
# away_team_gender                                         male
# away_team_group                                          None
# away_team_country_id                                       68
# away_team_country_name                                England
# away_team_managers_id                                   577.0
# away_team_managers_name                         Arsène Wenger
# away_team_managers_nickname                     Arsène Wenger
# away_team_managers_dob                    1949-10-22 00:00:00
# away_team_managers_country_id                            78.0
# away_team_managers_country_name                        France
# metadata_data_version                                   1.1.0
# metadata_shot_fidelity_version                              2
# metadata_xy_fidelity_version                                2
# competition_stage_id                                        1
# competition_stage_name                         Regular Season
# stadium_id                                              217.0
# stadium_name                                 Molineux Stadium
# stadium_country_id                                       68.0
# stadium_country_name                                  England
# referee_id                                                NaN
# referee_name                                              NaN
# referee_country_id                                        NaN
# referee_country_name                                      NaN
# Name: 0, dtype: object

# %%
df, df_related, df_freeze, df_tactics = parser.event(3749052)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3518 entries, 0 to 3517
# Data columns (total 76 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3518 non-null   object
#  1   index                           3518 non-null   int64
#  2   period                          3518 non-null   int64
#  3   timestamp                       3518 non-null   object
#  4   minute                          3518 non-null   int64
#  5   second                          3518 non-null   int64
#  6   possession                      3518 non-null   int64
#  7   duration                        2611 non-null   float64
#  8   match_id                        3518 non-null   int64
#  9   type_id                         3518 non-null   int64
#  10  type_name                       3518 non-null   object
#  11  possession_team_id              3518 non-null   int64
#  12  possession_team_name            3518 non-null   object
#  13  play_pattern_id                 3518 non-null   int64
#  14  play_pattern_name               3518 non-null   object
#  15  team_id                         3518 non-null   int64
#  16  team_name                       3518 non-null   object
#  17  tactics_formation               2 non-null      float64
#  18  off_camera                      52 non-null     float64
#  19  player_id                       3508 non-null   float64
#  20  player_name                     3508 non-null   object
#  21  position_id                     3508 non-null   float64
#  22  position_name                   3508 non-null   object
#  23  pass_recipient_id               907 non-null    float64
#  24  pass_recipient_name             907 non-null    object
#  25  pass_length                     954 non-null    float64
#  26  pass_angle                      954 non-null    float64
#  27  pass_height_id                  954 non-null    float64
#  28  pass_height_name                954 non-null    object
#  29  end_x                           1678 non-null   float64
#  30  end_y                           1678 non-null   float64
#  31  body_part_id                    943 non-null    float64
#  32  body_part_name                  943 non-null    object
#  33  sub_type_id                     454 non-null    float64
#  34  sub_type_name                   454 non-null    object
#  35  x                               3505 non-null   float64
#  36  y                               3505 non-null   float64
#  37  under_pressure                  824 non-null    float64
#  38  outcome_id                      657 non-null    float64
#  39  outcome_name                    657 non-null    object
#  40  counterpress                    144 non-null    float64
#  41  ball_recovery_recovery_failure  16 non-null     object
#  42  out                             32 non-null     float64
#  43  aerial_won                      52 non-null     object
#  44  foul_committed_offensive        7 non-null      object
#  45  foul_won_defensive              16 non-null     object
#  46  pass_switch                     30 non-null     object
#  47  dribble_overrun                 4 non-null      object
#  48  pass_cross                      23 non-null     object
#  49  pass_assisted_shot_id           20 non-null     object
#  50  pass_goal_assist                4 non-null      object
#  51  shot_statsbomb_xg               24 non-null     float64
#  52  end_z                           20 non-null     float64
#  53  shot_key_pass_id                20 non-null     object
#  54  technique_id                    44 non-null     float64
#  55  technique_name                  44 non-null     object
#  56  shot_first_time                 8 non-null      object
#  57  goalkeeper_position_id          24 non-null     float64
#  58  goalkeeper_position_name        24 non-null     object
#  59  foul_committed_card_id          3 non-null      float64
#  60  foul_committed_card_name        3 non-null      object
#  61  ball_recovery_offensive         2 non-null      object
#  62  pass_shot_assist                16 non-null     object
#  63  block_offensive                 1 non-null      object
#  64  pass_deflected                  2 non-null      object
#  65  bad_behaviour_card_id           1 non-null      float64
#  66  bad_behaviour_card_name         1 non-null      object
#  67  foul_committed_advantage        7 non-null      object
#  68  foul_won_advantage              7 non-null      object
#  69  dribble_nutmeg                  3 non-null      object
#  70  pass_cut_back                   1 non-null      object
#  71  substitution_replacement_id     2 non-null      float64
#  72  substitution_replacement_name   2 non-null      object
#  73  shot_open_goal                  1 non-null      object
#  74  pass_miscommunication           1 non-null      object
#  75  pass_no_touch                   1 non-null      object
# dtypes: float64(26), int64(10), object(40)
# memory usage: 2.0+ MB

# %%
df['outcome_name'].value_counts()
# Out:
# Incomplete         488
# Complete            23
# Success In Play     21
# Out                 20
# Lost In Play        19
# Won                 18
# Lost Out            15
# Off T               11
# Unknown             10
# Saved                5
# Goal                 4
# Blocked              4
# No Touch             3
# Pass Offside         3
# Success              3
# In Play Danger       2
# Success Out          2
# Tactical             2
# Saved Twice          1
# Touched Out          1
# Touched In           1
# Claim                1
# Name: outcome_name, dtype: int64

# %%
def getUniquePlayers():
  return df['player_name'].value_counts()
getUniquePlayers()
# Out:
# Eduardo César Daude Gaspar          255
# Robert Pirès                        241
# Patrick Vieira                      239
# Laureano Bisan-Etame Mayer          235
# Thierry Henry                       222
# Ashley Cole                         215
# Ioan Viorel Ganea                   213
# Gilberto Aparecido da Silva         207
# Alex Rae                            163
# Colin Cameron                       152
# Lee Naylor                          141
# Carl Cort                           136
# Denis Irwin                         133
# Mark Kennedy                        130
# Kenny Miller                        123
# Dennis Bergkamp                     118
# Kolo Habib Touré                    116
# Sulzeer Jeremiah ''Sol' Campbell    108
# Paul Jones                           88
# Jens Lehmann                         71
# José Antonio Reyes Calderón          69
# Paul Butler                          69
# Jody Craddock                        41
# Steffen Iversen                      23
# Name: player_name, dtype: int64

# %% [markdown]
# # Plotting Pass Maps

# %%
def generatePlayerPassMapsGrid(team_name):
  # filtering to passes by team_name players
  team_passes = (df.type_name == 'Pass') & (df.team_name == team_name) & (df.sub_type_name != "Throw-in")
  # selecting only relevant columns for the pass map
  team_passes = df.loc[team_passes, ['x', 'y', 'end_x', 'end_y', 'player_name','outcome_name']]
  #get the list of all players who made a pass
  names = team_passes['player_name'].unique()
  #draw 4x4 pitches
  pitch = Pitch(line_color='white',pitch_color='#02540b',pad_top=20)
  fig, axs = pitch.grid(ncols = 4, nrows = 3, grid_height=0.85, title_height=0.06, axis=False,endnote_height=0.04, title_space=0.04, endnote_space=0.01)
  plt.figure(figsize=(14,10))
  #for each player
  for name, ax in zip(names, axs['pitch'].flat[:len(names)]):
    #take only passes by this player
    player_df = team_passes.loc[team_passes["player_name"] == name]
    #put player name over the plot
    ax.text(60, -10, name.split()[0]+":"+str(len(player_df))+" passes",ha='center', va='center', fontsize=14)
    #scatter -  plots the player position with 0.2 alpha(visibility)
    #pitch.scatter(player_df.x, player_df.y, alpha = 0.2, s = 50, color = "blue", ax=ax)
    #plot pass arrows
    #pitch.arrows(player_df.x, player_df.y,player_df.end_x, player_df.end_y, color = "blue", ax=ax, width=1)
    # plotting arrows one by one, red or green based on if its incomplete or not
    for i in player_df.index:
      x=player_df['x'][i]
      y = player_df['y'][i]
      dx = player_df['end_x'][i] - player_df['x'][i]
      dy = player_df['end_y'][i] - player_df['y'][i]
      if df['outcome_name'][i] != 'Incomplete':
        ax.arrow(x,y,dx,dy,color='#0dff00',length_includes_head=True,head_width=1,head_length=0.8)
        pitch.scatter(player_df['x'][i],player_df['y'][i],color='#0dff00',ax=ax)
      else:
        ax.arrow(x,y,dx,dy,color='red',length_includes_head=True,head_width=1,head_length=0.8)
        pitch.scatter(player_df['x'][i],player_df['y'][i],color='red',ax=ax)

    #We have more than enough pitches - remove them
    for ax in axs['pitch'][-1, 25 - len(names):]:
      ax.remove(ax)

    #Another way to set title using mplsoccer
    axs['title'].text(0.5, 0.5, team_name+" pass maps", ha='center', va='center', fontsize=20)

# %%
generatePlayerPassMapsGrid('Wolverhampton Wanderers')

# %%
generatePlayerPassMapsGrid('Arsenal')

# %% [markdown]
# # Plotting Heatmaps

# %%
def generatePlayerHeatmapGrid(team_name):
    # filtering to passes by team_name players
    team_passes = (df.type_name == 'Pass') & (df.team_name == team_name) & (df.sub_type_name != "Throw-in")
    # selecting only relevant columns for the pass map
    team_passes = df.loc[team_passes, ['x', 'y', 'end_x', 'end_y', 'player_name','outcome_name']]
    #get the list of all players who made a pass
    names = team_passes['player_name'].unique()
    #draw 4x4 pitches
    pitch = Pitch(line_color='white',pitch_color='#02540b')
    fig, axs = pitch.grid(ncols = 4, nrows = 3, grid_height=0.85, title_height=0.06, axis=False,endnote_height=0.04, title_space=0.04, endnote_space=0.01)
    plt.figure(figsize=(14,10))
    #for each player
    for name, ax in zip(names, axs['pitch'].flat[:len(names)]):
        #take only passes by this player
        player_df = team_passes.loc[team_passes["player_name"] == name]
        #put player name over the plot
        ax.text(60, -10, name.split()[-1],ha='center', va='center', fontsize=14)
        #Create the heatmap
        pitch.kdeplot(x=player_df['x'], y=player_df['y'], shade = True, shade_lowest=False, alpha=.5, n_levels=10, cmap = 'plasma', ax=ax)
    #We have more than enough pitches - remove them
    for ax in axs['pitch'][-1, 25 - len(names):]:
        ax.remove(ax)
    
    #Another way to set title using mplsoccer
    axs['title'].text(0.5, 0.5, team_name+" Heatmaps", ha='center', va='center', fontsize=20)

# %%
generatePlayerHeatmapGrid("Wolverhampton Wanderers")
# Out:
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)

# %%
generatePlayerHeatmapGrid("Arsenal")
# Out:
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# /usr/local/lib/python3.9/dist-packages/mplsoccer/_pitch_plot.py:172: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)

# %% [markdown]
# # Plotting Passing Network

# %%
def generatePassingNetwork(team_name):
    #check for index of first sub
    sub = df.loc[df["type_name"] == "Substitution"].loc[df["team_name"] == team_name].iloc[0]["index"]
    #make df with successfull passes by Real Madrid until the first substitution
    rm_passes = (df.type_name == 'Pass') & (df.team_name == team_name) & (df.index < sub) & (df.outcome_name.isnull()) & (df.sub_type_name != "Throw-in")
    #taking necessary columns
    rm_pass = df.loc[rm_passes, ['x', 'y', 'end_x', 'end_y', "player_name", "pass_recipient_name"]]
    #adjusting that only the surname of a player is presented.
    rm_pass["player_name"] = rm_pass["player_name"].apply(lambda x: str(x).split()[-1])
    rm_pass["pass_recipient_name"] = rm_pass["pass_recipient_name"].apply(lambda x: str(x).split()[-1])

    scatter_df = pd.DataFrame()
    for i, name in enumerate(rm_pass["player_name"].unique()):
        passx = rm_pass.loc[rm_pass["player_name"] == name]["x"].to_numpy()
        recx = rm_pass.loc[rm_pass["pass_recipient_name"] == name]["end_x"].to_numpy()
        passy = rm_pass.loc[rm_pass["player_name"] == name]["y"].to_numpy()
        recy = rm_pass.loc[rm_pass["pass_recipient_name"] == name]["end_y"].to_numpy()
        scatter_df.at[i, "player_name"] = name
        #make sure that x and y location for each circle representing the player is the average of passes and receptions
        scatter_df.at[i, "x"] = np.mean(np.concatenate([passx, recx]))
        scatter_df.at[i, "y"] = np.mean(np.concatenate([passy, recy]))
        #calculate number of passes
        scatter_df.at[i, "no"] = rm_pass.loc[rm_pass["player_name"] == name].count().iloc[0]
    #adjust the size of a circle so that the player who made more passes 
    scatter_df['marker_size'] = (scatter_df["no"] / scatter_df["no"].max() * 1500)

    #counting passes between players
    rm_pass["pair_key"] = rm_pass.apply(lambda x: "_".join(sorted([x["player_name"], x["pass_recipient_name"]])), axis=1)
    lines_df = rm_pass.groupby(["pair_key"]).x.count().reset_index()
    lines_df.rename({'x':'pass_count'}, axis='columns', inplace=True)
    #setting a threshold. You can try to investigate how it changes when you change it.
    lines_df = lines_df[lines_df['pass_count']>2]

     #plot once again pitch and vertices
    pitch = Pitch(line_color='white',pitch_color='#02540b')
    fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                         endnote_height=0.04, title_space=0, endnote_space=0)
    pitch.scatter(scatter_df.x, scatter_df.y, s=scatter_df.marker_size, color='#2f5fed', edgecolors='grey', linewidth=1, alpha=1, ax=ax["pitch"], zorder = 3)
    for i, row in scatter_df.iterrows():
        pitch.annotate(row.player_name, xy=(row.x, row.y), c='black', va='center', ha='center', weight = "bold", size=16, ax=ax["pitch"], zorder = 4)
    for i, row in lines_df.iterrows():
            player1 = row["pair_key"].split("_")[0]
            player2 = row['pair_key'].split("_")[1]
            #take the average location of players to plot a line between them 
            player1_x = scatter_df.loc[scatter_df["player_name"] == player1]['x'].iloc[0]
            player1_y = scatter_df.loc[scatter_df["player_name"] == player1]['y'].iloc[0]
            player2_x = scatter_df.loc[scatter_df["player_name"] == player2]['x'].iloc[0]
            player2_y = scatter_df.loc[scatter_df["player_name"] == player2]['y'].iloc[0]
            num_passes = row["pass_count"]
             #adjust the line width so that the more passes, the wider the line
            line_width = (num_passes / lines_df['pass_count'].max() * 10)
            #plot lines on the pitch
            pitch.lines(player1_x, player1_y, player2_x, player2_y,
                            alpha=1, lw=line_width, zorder=2, color="#2f5fed", ax = ax["pitch"])
    fig.suptitle(team_name+"'s Passing Network", fontsize = 20)

# %%
generatePassingNetwork("Wolverhampton Wanderers")

# %%
generatePassingNetwork("Arsenal")

# %% [markdown]
# # Plotting ShotMap

# %%
def generateTeamxGDataFrame(team_name):
    xg = df[['team_name','minute','type_name','shot_statsbomb_xg','x','y']]
    team_xg = xg[xg['team_name']==team_name].reset_index()
    return team_xg
def generateCombinedShotMap(team1,team2):
    team1_xg = generateTeamxGDataFrame(team1)
    team2_xg = generateTeamxGDataFrame(team2)
    team1_shots = team1_xg[team1_xg.type_name=='Shot']
    team2_shots = team2_xg[team2_xg.type_name=='Shot']
    pitch = Pitch(line_color='white',pitch_color='#02540b')
    fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,endnote_height=0.04, title_space=0, endnote_space=0)
    pitch.scatter(team1_shots.x, team1_shots.y, alpha = 0.3, s = team1_shots.shot_statsbomb_xg*5000, color = "red", ax=ax['pitch'],)
    pitch.scatter(120-team2_shots.x, 80-team2_shots.y, alpha = 0.3, s = team2_shots.shot_statsbomb_xg*5000, color = "blue", ax=ax['pitch'],)
    ax['pitch'].text(5, 5, team2 + ' shots',color='white',size=20)
    ax['pitch'].text(80, 5, team1 + ' shots',color='white',size=20)

# %%
generateCombinedShotMap('Wolverhampton Wanderers','Arsenal')
